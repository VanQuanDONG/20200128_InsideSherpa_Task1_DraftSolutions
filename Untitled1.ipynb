# %%
import pandas as pd

# %%
data= pd.read_csv('planecrashinfo_20181121001952.csv')

# %%
data
# Out:
#                     date     time                            location  \
# 0     September 17, 1908    17:18                 Fort Myer, Virginia
# 1     September 07, 1909        ?             Juvisy-sur-Orge, France
# 2          July 12, 1912    06:30           Atlantic City, New Jersey
# 3        August 06, 1913        ?  Victoria, British Columbia, Canada
# 4     September 09, 1913  c 18:30                  Over the North Sea
# ...                  ...      ...                                 ...
# 5778       July 10, 2018     0744              Pretoria, South Africa
# 5779     August 04, 2018     1655                  Flims, Switzerland
# 5780  September 28, 2018     1010                   Chuuk, Micronesia
# 5781    October 29, 2018     0631              Off Jakarta, Indonesia
# 5782   November 06, 2018     0253                  Georgetown, Guyana
#
#                     operator flight_no                     route  \
# ...

# %%
pd.to_datetime(data['date'])
# Out:
# 0      1908-09-17
# 1      1909-09-07
# 2      1912-07-12
# 3      1913-08-06
# 4      1913-09-09
#           ...
# 5778   2018-07-10
# 5779   2018-08-04
# 5780   2018-09-28
# 5781   2018-10-29
# 5782   2018-11-06
# Name: date, Length: 5783, dtype: datetime64[ns]

# %%
data.columns
# Out:
# Index(['date', 'time', 'location', 'operator', 'flight_no', 'route', 'ac_type',
#        'registration', 'cn_ln', 'aboard', 'fatalities', 'ground', 'summary'],
#       dtype='object')

# %%
len(data['operator'].unique())
# Out:
# 2821
