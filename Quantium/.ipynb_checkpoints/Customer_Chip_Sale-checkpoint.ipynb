# %% [markdown]
# ## Project, Van Quan DONG

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Import data

# %%
customer = pd.read_csv('QVI_purchase_behaviour1.csv')

# %%
potato = pd.read_excel('QVI_transaction_data1.xlsx')

# %%
customer
# Out:
#        LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0                1000   YOUNG SINGLES/COUPLES          Premium
# 1                1002   YOUNG SINGLES/COUPLES       Mainstream
# 2                1003          YOUNG FAMILIES           Budget
# 3                1004   OLDER SINGLES/COUPLES       Mainstream
# 4                1005  MIDAGE SINGLES/COUPLES       Mainstream
# ...               ...                     ...              ...
# 72632         2370651  MIDAGE SINGLES/COUPLES       Mainstream
# 72633         2370701          YOUNG FAMILIES       Mainstream
# 72634         2370751          YOUNG FAMILIES          Premium
# 72635         2370961          OLDER FAMILIES           Budget
# 72636         2373711   YOUNG SINGLES/COUPLES       Mainstream
#
# [72637 rows x 3 columns]

# %%
potato
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       43390          1            1000       1         5
# 1       43599          1            1307     348        66
# 2       43605          1            1343     383        61
# 3       43329          2            2373     974        69
# 4       43330          2            2426    1038       108
# ...       ...        ...             ...     ...       ...
# 264831  43533        272          272319  270088        89
# 264832  43325        272          272358  270154        74
# 264833  43410        272          272379  270187        51
# 264834  43461        272          272379  270188        42
# 264835  43365        272          272380  270189        74
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# 1                       CCs Nacho Cheese    175g         3        6.3
# 2         Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3         Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4       Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8
# ...                                          ...       ...        ...
# 264831   Kettle Sweet Chilli And Sour Cream 175g         2       10.8
# 264832             Tostitos Splash Of  Lime 175g         1        4.4
# 264833                  Doritos Mexicana    170g         2        8.8
# 264834   Doritos Corn Chip Mexican Jalapeno 150g         2        7.8
# 264835             Tostitos Splash Of  Lime 175g         2        8.8
#
# [264836 rows x 8 columns]

# %% [markdown]
# # Data exploration

# %%
potato.describe()
# Out:
#                 DATE     STORE_NBR  LYLTY_CARD_NBR        TXN_ID  \
# count  264836.000000  264836.00000    2.648360e+05  2.648360e+05
# mean    43464.036260     135.08011    1.355495e+05  1.351583e+05
# std       105.389282      76.78418    8.057998e+04  7.813303e+04
# min     43282.000000       1.00000    1.000000e+03  1.000000e+00
# 25%     43373.000000      70.00000    7.002100e+04  6.760150e+04
# 50%     43464.000000     130.00000    1.303575e+05  1.351375e+05
# 75%     43555.000000     203.00000    2.030942e+05  2.027012e+05
# max     43646.000000     272.00000    2.373711e+06  2.415841e+06
#
#             PROD_NBR       PROD_QTY      TOT_SALES
# count  264836.000000  264836.000000  264836.000000
# mean       56.583157       1.907309       7.304200
# std        32.826638       0.643654       3.083226
# min         1.000000       1.000000       1.500000
# 25%        28.000000       2.000000       5.400000
# 50%        56.000000       2.000000       7.400000
# 75%        85.000000       2.000000       9.200000
# max       114.000000     200.000000     650.000000

# %%
potato.shape
# Out:
# (264836, 8)

# %%
potato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DATE            264836 non-null  int64
#  1   STORE_NBR       264836 non-null  int64
#  2   LYLTY_CARD_NBR  264836 non-null  int64
#  3   TXN_ID          264836 non-null  int64
#  4   PROD_NBR        264836 non-null  int64
#  5   PROD_NAME       264836 non-null  object
#  6   PROD_QTY        264836 non-null  int64
#  7   TOT_SALES       264836 non-null  float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 16.2+ MB

# %% [markdown]
# > - note: Date should be transform to approriate format,

# %% [markdown]
# **There are mutual columns that link the customer data with the potato data**

# %%
potato.set_index('LYLTY_CARD_NBR').join(customer.set_index('LYLTY_CARD_NBR'))
# Out:
#                  DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# LYLTY_CARD_NBR
# 1000            43390          1       1         5
# 1002            43359          1       2        58
# 1003            43531          1       3        52
# 1003            43532          1       4       106
# 1004            43406          1       5        96
# ...               ...        ...     ...       ...
# 2370701         43442         88  240378        24
# 2370751         43374         88  240394        60
# 2370961         43397         88  240480        70
# 2370961         43400         88  240481        65
# 2373711         43448         88  241815        16
#
#                                                PROD_NAME  PROD_QTY  TOT_SALES  \
# LYLTY_CARD_NBR
# 1000              Natural Chip        Compny SeaSalt175g         2        6.0
# 1002               Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7
# 1003               Grain Waves Sour    Cream&Chives 210G         1        3.6
# 1003              Natural ChipCo      Hony Soy Chckn175g         1        3.0
# 1004                      WW Original Stacked Chips 160g         1        1.9
# ...                                                  ...       ...        ...
# 2370701            Grain Waves         Sweet Chilli 210g         2        7.2
# 2370751             Kettle Tortilla ChpsFeta&Garlic 150g         2        9.2
# 2370961          Tyrrells Crisps     Lightly Salted 165g         2        8.4
# 2370961         Old El Paso Salsa   Dip Chnky Tom Ht300g         2       10.2
# 2373711         Smiths Crinkle Chips Salt & Vinegar 330g         2       11.4
#
#                             LIFESTAGE PREMIUM_CUSTOMER
# LYLTY_CARD_NBR
# 1000            YOUNG SINGLES/COUPLES          Premium
# 1002            YOUNG SINGLES/COUPLES       Mainstream
# 1003                   YOUNG FAMILIES           Budget
# 1003                   YOUNG FAMILIES           Budget
# 1004            OLDER SINGLES/COUPLES       Mainstream
# ...                               ...              ...
# 2370701                YOUNG FAMILIES       Mainstream
# 2370751                YOUNG FAMILIES          Premium
# 2370961                OLDER FAMILIES           Budget
# 2370961                OLDER FAMILIES           Budget
# 2373711         YOUNG SINGLES/COUPLES       Mainstream
#
# [264836 rows x 9 columns]

# %%
merge = customer.set_index('LYLTY_CARD_NBR').join(potato.set_index('LYLTY_CARD_NBR'))

# %%
merge.reset_index()
# Out:
#         LYLTY_CARD_NBR              LIFESTAGE PREMIUM_CUSTOMER   DATE  \
# 0                 1000  YOUNG SINGLES/COUPLES          Premium  43390
# 1                 1002  YOUNG SINGLES/COUPLES       Mainstream  43359
# 2                 1003         YOUNG FAMILIES           Budget  43531
# 3                 1003         YOUNG FAMILIES           Budget  43532
# 4                 1004  OLDER SINGLES/COUPLES       Mainstream  43406
# ...                ...                    ...              ...    ...
# 264831         2370701         YOUNG FAMILIES       Mainstream  43442
# 264832         2370751         YOUNG FAMILIES          Premium  43374
# 264833         2370961         OLDER FAMILIES           Budget  43397
# 264834         2370961         OLDER FAMILIES           Budget  43400
# 264835         2373711  YOUNG SINGLES/COUPLES       Mainstream  43448
#
#         STORE_NBR  TXN_ID  PROD_NBR                                 PROD_NAME  \
# 0               1       1         5    Natural Chip        Compny SeaSalt175g
# 1               1       2        58     Red Rock Deli Chikn&Garlic Aioli 150g
# 2               1       3        52     Grain Waves Sour    Cream&Chives 210G
# 3               1       4       106    Natural ChipCo      Hony Soy Chckn175g
# 4               1       5        96            WW Original Stacked Chips 160g
# ...           ...     ...       ...                                       ...
# 264831         88  240378        24     Grain Waves         Sweet Chilli 210g
# 264832         88  240394        60      Kettle Tortilla ChpsFeta&Garlic 150g
# 264833         88  240480        70   Tyrrells Crisps     Lightly Salted 165g
# 264834         88  240481        65  Old El Paso Salsa   Dip Chnky Tom Ht300g
# 264835         88  241815        16  Smiths Crinkle Chips Salt & Vinegar 330g
#
#         PROD_QTY  TOT_SALES
# 0              2        6.0
# 1              1        2.7
# 2              1        3.6
# 3              1        3.0
# 4              1        1.9
# ...          ...        ...
# 264831         2        7.2
# 264832         2        9.2
# 264833         2        8.4
# 264834         2       10.2
# 264835         2       11.4
#
# [264836 rows x 10 columns]

# %% [markdown]
# **Transform DATE columns in to approriate date**

# %%
merge['DATE'] = pd.to_datetime(merge['DATE'], origin = '1899-12-30',errors='coerce',unit='d' )

# %%
merge.sort_values(by = ['DATE'])
# Out:
#                              LIFESTAGE PREMIUM_CUSTOMER       DATE  STORE_NBR  \
# LYLTY_CARD_NBR
# 78115           MIDAGE SINGLES/COUPLES       Mainstream 2018-07-01         78
# 220035           YOUNG SINGLES/COUPLES       Mainstream 2018-07-01        220
# 141141           YOUNG SINGLES/COUPLES       Mainstream 2018-07-01        141
# 59307            YOUNG SINGLES/COUPLES       Mainstream 2018-07-01         59
# 39086            OLDER SINGLES/COUPLES       Mainstream 2018-07-01         39
# ...                                ...              ...        ...        ...
# 156186           OLDER SINGLES/COUPLES          Premium 2019-06-30        156
# 110247           OLDER SINGLES/COUPLES          Premium 2019-06-30        110
# 187156           YOUNG SINGLES/COUPLES       Mainstream 2019-06-30        187
# 104098                  OLDER FAMILIES           Budget 2019-06-30        104
# 53382                         RETIREES           Budget 2019-06-30         53
#
#                 TXN_ID  PROD_NBR                                 PROD_NAME  \
# LYLTY_CARD_NBR
# 78115            76138        87   Infuzions BBQ Rib   Prawn Crackers 110g
# 220035          219501        81           Pringles Original   Crisps 134g
# 141141          142377        89   Kettle Sweet Chilli And Sour Cream 175g
# 59307            55832        17        Kettle Sensations   BBQ&Maple 150g
# 39086            35147       107  Smiths Crinkle Cut  French OnionDip 150g
# ...                ...       ...                                       ...
# 156186          157872        93   Doritos Corn Chip Southern Chicken 150g
# 110247          113041        88          Kettle Honey Soy    Chicken 175g
# 187156          189059        77     Doritos Corn Chips  Nacho Cheese 170g
# 104098          104313       114     Kettle Sensations   Siracha Lime 150g
# 53382            47672        39     Smiths Crinkle Cut  Tomato Salsa 150g
#
#                 PROD_QTY  TOT_SALES
# LYLTY_CARD_NBR
# 78115                  2        7.6
# 220035                 2        7.4
# 141141                 2       10.8
# 59307                  2        9.2
# 39086                  2        5.2
# ...                  ...        ...
# 156186                 2        7.8
# 110247                 2       10.8
# 187156                 2        8.8
# 104098                 2        9.2
# 53382                  2        5.2
#
# [264836 rows x 9 columns]

# %%
merge = merge.reset_index()

# %%
merge.isna().sum()
# Out:
# LYLTY_CARD_NBR      0
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# DATE                0
# STORE_NBR           0
# TXN_ID              0
# PROD_NBR            0
# PROD_NAME           0
# PROD_QTY            0
# TOT_SALES           0
# dtype: int64

# %%
merge.groupby(merge['PREMIUM_CUSTOMER']).count()['PROD_QTY'].reset_index(name = 'count')
# Out:
#   PREMIUM_CUSTOMER   count
# 0           Budget   93157
# 1       Mainstream  101988
# 2          Premium   69691

# %% [markdown]
# # Examine, removing outlier

# %%
merge
# Out:
#         LYLTY_CARD_NBR              LIFESTAGE PREMIUM_CUSTOMER       DATE  \
# 0                 1000  YOUNG SINGLES/COUPLES          Premium 2018-10-17
# 1                 1002  YOUNG SINGLES/COUPLES       Mainstream 2018-09-16
# 2                 1003         YOUNG FAMILIES           Budget 2019-03-07
# 3                 1003         YOUNG FAMILIES           Budget 2019-03-08
# 4                 1004  OLDER SINGLES/COUPLES       Mainstream 2018-11-02
# ...                ...                    ...              ...        ...
# 264831         2370701         YOUNG FAMILIES       Mainstream 2018-12-08
# 264832         2370751         YOUNG FAMILIES          Premium 2018-10-01
# 264833         2370961         OLDER FAMILIES           Budget 2018-10-24
# 264834         2370961         OLDER FAMILIES           Budget 2018-10-27
# 264835         2373711  YOUNG SINGLES/COUPLES       Mainstream 2018-12-14
#
#         STORE_NBR  TXN_ID  PROD_NBR                                 PROD_NAME  \
# 0               1       1         5    Natural Chip        Compny SeaSalt175g
# 1               1       2        58     Red Rock Deli Chikn&Garlic Aioli 150g
# 2               1       3        52     Grain Waves Sour    Cream&Chives 210G
# 3               1       4       106    Natural ChipCo      Hony Soy Chckn175g
# 4               1       5        96            WW Original Stacked Chips 160g
# ...           ...     ...       ...                                       ...
# 264831         88  240378        24     Grain Waves         Sweet Chilli 210g
# 264832         88  240394        60      Kettle Tortilla ChpsFeta&Garlic 150g
# 264833         88  240480        70   Tyrrells Crisps     Lightly Salted 165g
# 264834         88  240481        65  Old El Paso Salsa   Dip Chnky Tom Ht300g
# 264835         88  241815        16  Smiths Crinkle Chips Salt & Vinegar 330g
#
#         PROD_QTY  TOT_SALES
# 0              2        6.0
# 1              1        2.7
# 2              1        3.6
# 3              1        3.0
# 4              1        1.9
# ...          ...        ...
# 264831         2        7.2
# 264832         2        9.2
# 264833         2        8.4
# 264834         2       10.2
# 264835         2       11.4
#
# [264836 rows x 10 columns]

# %%
merge['PROD_QTY'].unique()
# Out:
# array([  2,   1,   4,   3,   5, 200])

# %%
merge.loc[merge['PROD_QTY']>100]
# Out:
#         LYLTY_CARD_NBR       LIFESTAGE PREMIUM_CUSTOMER       DATE  STORE_NBR  \
# 221625          226000  OLDER FAMILIES          Premium 2018-08-19        226
# 221626          226000  OLDER FAMILIES          Premium 2019-05-20        226
#
#         TXN_ID  PROD_NBR                         PROD_NAME  PROD_QTY  \
# 221625  226201         4  Dorito Corn Chp     Supreme 380g       200
# 221626  226210         4  Dorito Corn Chp     Supreme 380g       200
#
#         TOT_SALES
# 221625      650.0
# 221626      650.0

# %%
merge = merge.drop([221625,221626])

# %%
merge['PROD_QTY'].plot()
# Out:
# <AxesSubplot:>

# %%
merge['TOT_SALES'].plot()
# Out:
# <AxesSubplot:>

# %%
merge['TOT_SALES'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# > - There are outlier, need to detect and remove

# %%
merge['TOT_SALES'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
merge['TOT_SALES'].describe()
# Out:
# count    264834.000000
# mean          7.299346
# std           2.527241
# min           1.500000
# 25%           5.400000
# 50%           7.400000
# 75%           9.200000
# max          29.500000
# Name: TOT_SALES, dtype: float64

# %%
merge = merge.loc[~(merge['TOT_SALES']>(merge['TOT_SALES'].mean()+3*merge['TOT_SALES'].std()))]

# %%
merge
# Out:
#         LYLTY_CARD_NBR              LIFESTAGE PREMIUM_CUSTOMER       DATE  \
# 0                 1000  YOUNG SINGLES/COUPLES          Premium 2018-10-17
# 1                 1002  YOUNG SINGLES/COUPLES       Mainstream 2018-09-16
# 2                 1003         YOUNG FAMILIES           Budget 2019-03-07
# 3                 1003         YOUNG FAMILIES           Budget 2019-03-08
# 4                 1004  OLDER SINGLES/COUPLES       Mainstream 2018-11-02
# ...                ...                    ...              ...        ...
# 264831         2370701         YOUNG FAMILIES       Mainstream 2018-12-08
# 264832         2370751         YOUNG FAMILIES          Premium 2018-10-01
# 264833         2370961         OLDER FAMILIES           Budget 2018-10-24
# 264834         2370961         OLDER FAMILIES           Budget 2018-10-27
# 264835         2373711  YOUNG SINGLES/COUPLES       Mainstream 2018-12-14
#
#         STORE_NBR  TXN_ID  PROD_NBR                                 PROD_NAME  \
# 0               1       1         5    Natural Chip        Compny SeaSalt175g
# 1               1       2        58     Red Rock Deli Chikn&Garlic Aioli 150g
# 2               1       3        52     Grain Waves Sour    Cream&Chives 210G
# 3               1       4       106    Natural ChipCo      Hony Soy Chckn175g
# 4               1       5        96            WW Original Stacked Chips 160g
# ...           ...     ...       ...                                       ...
# 264831         88  240378        24     Grain Waves         Sweet Chilli 210g
# 264832         88  240394        60      Kettle Tortilla ChpsFeta&Garlic 150g
# 264833         88  240480        70   Tyrrells Crisps     Lightly Salted 165g
# 264834         88  240481        65  Old El Paso Salsa   Dip Chnky Tom Ht300g
# 264835         88  241815        16  Smiths Crinkle Chips Salt & Vinegar 330g
#
#         PROD_QTY  TOT_SALES
# 0              2        6.0
# 1              1        2.7
# 2              1        3.6
# 3              1        3.0
# 4              1        1.9
# ...          ...        ...
# 264831         2        7.2
# 264832         2        9.2
# 264833         2        8.4
# 264834         2       10.2
# 264835         2       11.4
#
# [264258 rows x 10 columns]

# %%
merge['TOT_SALES'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
a = merge.groupby('DATE').count().reset_index()['DATE'].reset_index()

# %%
a
# Out:
#      index       DATE
# 0        0 2018-07-01
# 1        1 2018-07-02
# 2        2 2018-07-03
# 3        3 2018-07-04
# 4        4 2018-07-05
# ..     ...        ...
# 359    359 2019-06-26
# 360    360 2019-06-27
# 361    361 2019-06-28
# 362    362 2019-06-29
# 363    363 2019-06-30
#
# [364 rows x 2 columns]

# %%
pd.date_range(start="2018-07-01",end="2019-06-30").difference(a['DATE'])
# Out:
# DatetimeIndex(['2018-12-25'], dtype='datetime64[ns]', freq=None)

# %%
#ax = plt.plot(merge['DATE'], merge[''])

# %%
b = merge.groupby('DATE').count()['PROD_QTY']

# %%
b = b.reset_index()
b
# Out:
#           DATE  PROD_QTY
# 0   2018-07-01       724
# 1   2018-07-02       711
# 2   2018-07-03       722
# 3   2018-07-04       714
# 4   2018-07-05       712
# ..         ...       ...
# 359 2019-06-26       723
# 360 2019-06-27       709
# 361 2019-06-28       730
# 362 2019-06-29       745
# 363 2019-06-30       744
#
# [364 rows x 2 columns]

# %%
plt.bar(b['DATE'],b['PROD_QTY'])
plt.figure(figsize= (1000,1000))

# %%
b.loc[364] = [2018,0]
b
pd.to_datetime(2018/12/25)
# Out:
# Timestamp('1970-01-01 00:00:00.000000006')

# %%
merge['DATE']
# Out:
# 0        2018-10-17
# 1        2018-09-16
# 2        2019-03-07
# 3        2019-03-08
# 4        2018-11-02
#             ...
# 264253   2018-12-08
# 264254   2018-10-01
# 264255   2018-10-24
# 264256   2018-10-27
# 264257   2018-12-14
# Name: DATE, Length: 264258, dtype: datetime64[ns]

# %%
ProductWeight = merge['PROD_NAME'].str.extractall('(\d+)')

# %%
ProductWeight = ProductWeight.reset_index()

# %%
merge = merge.reset_index()

# %%
ProductWeight = ProductWeight.rename(columns = {0: 'weight'})

# %%
ProductWeight = ProductWeight['weight'].reset_index()

# %%
merge['weight'] = ProductWeight['weight']

# %%
merge
# Out:
#          index  LYLTY_CARD_NBR              LIFESTAGE PREMIUM_CUSTOMER  \
# 0            0            1000  YOUNG SINGLES/COUPLES          Premium
# 1            1            1002  YOUNG SINGLES/COUPLES       Mainstream
# 2            2            1003         YOUNG FAMILIES           Budget
# 3            3            1003         YOUNG FAMILIES           Budget
# 4            4            1004  OLDER SINGLES/COUPLES       Mainstream
# ...        ...             ...                    ...              ...
# 264253  264831         2370701         YOUNG FAMILIES       Mainstream
# 264254  264832         2370751         YOUNG FAMILIES          Premium
# 264255  264833         2370961         OLDER FAMILIES           Budget
# 264256  264834         2370961         OLDER FAMILIES           Budget
# 264257  264835         2373711  YOUNG SINGLES/COUPLES       Mainstream
#
#              DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0      2018-10-17          1       1         5
# 1      2018-09-16          1       2        58
# 2      2019-03-07          1       3        52
# 3      2019-03-08          1       4       106
# 4      2018-11-02          1       5        96
# ...           ...        ...     ...       ...
# 264253 2018-12-08         88  240378        24
# 264254 2018-10-01         88  240394        60
# 264255 2018-10-24         88  240480        70
# 264256 2018-10-27         88  240481        65
# 264257 2018-12-14         88  241815        16
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES weight
# 0         Natural Chip        Compny SeaSalt175g         2        6.0    175
# 1          Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7    150
# 2          Grain Waves Sour    Cream&Chives 210G         1        3.6    210
# 3         Natural ChipCo      Hony Soy Chckn175g         1        3.0    175
# 4                 WW Original Stacked Chips 160g         1        1.9    160
# ...                                          ...       ...        ...    ...
# 264253     Grain Waves         Sweet Chilli 210g         2        7.2    210
# 264254      Kettle Tortilla ChpsFeta&Garlic 150g         2        9.2    150
# 264255   Tyrrells Crisps     Lightly Salted 165g         2        8.4    165
# 264256  Old El Paso Salsa   Dip Chnky Tom Ht300g         2       10.2    300
# 264257  Smiths Crinkle Chips Salt & Vinegar 330g         2       11.4    330
#
# [264258 rows x 12 columns]

# %%
merge['weight'] = ProductWeight['weight']

# %%
ProductWeight['weight']
# Out:
# 0         175
# 1         150
# 2         210
# 3         175
# 4         160
#          ...
# 264253    210
# 264254    150
# 264255    165
# 264256    300
# 264257    330
# Name: weight, Length: 264258, dtype: object

# %%
merge
# Out:
#          index  LYLTY_CARD_NBR              LIFESTAGE PREMIUM_CUSTOMER  \
# 0            0            1000  YOUNG SINGLES/COUPLES          Premium
# 1            1            1002  YOUNG SINGLES/COUPLES       Mainstream
# 2            2            1003         YOUNG FAMILIES           Budget
# 3            3            1003         YOUNG FAMILIES           Budget
# 4            4            1004  OLDER SINGLES/COUPLES       Mainstream
# ...        ...             ...                    ...              ...
# 264253  264831         2370701         YOUNG FAMILIES       Mainstream
# 264254  264832         2370751         YOUNG FAMILIES          Premium
# 264255  264833         2370961         OLDER FAMILIES           Budget
# 264256  264834         2370961         OLDER FAMILIES           Budget
# 264257  264835         2373711  YOUNG SINGLES/COUPLES       Mainstream
#
#              DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0      2018-10-17          1       1         5
# 1      2018-09-16          1       2        58
# 2      2019-03-07          1       3        52
# 3      2019-03-08          1       4       106
# 4      2018-11-02          1       5        96
# ...           ...        ...     ...       ...
# 264253 2018-12-08         88  240378        24
# 264254 2018-10-01         88  240394        60
# 264255 2018-10-24         88  240480        70
# 264256 2018-10-27         88  240481        65
# 264257 2018-12-14         88  241815        16
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES weight
# 0         Natural Chip        Compny SeaSalt175g         2        6.0    175
# 1          Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7    150
# 2          Grain Waves Sour    Cream&Chives 210G         1        3.6    210
# 3         Natural ChipCo      Hony Soy Chckn175g         1        3.0    175
# 4                 WW Original Stacked Chips 160g         1        1.9    160
# ...                                          ...       ...        ...    ...
# 264253     Grain Waves         Sweet Chilli 210g         2        7.2    210
# 264254      Kettle Tortilla ChpsFeta&Garlic 150g         2        9.2    150
# 264255   Tyrrells Crisps     Lightly Salted 165g         2        8.4    165
# 264256  Old El Paso Salsa   Dip Chnky Tom Ht300g         2       10.2    300
# 264257  Smiths Crinkle Chips Salt & Vinegar 330g         2       11.4    330
#
# [264258 rows x 12 columns]

# %%
ProductWeight.drop(columns= ['level_0'], inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 ProductWeight.drop(columns= ['level_0'], inplace= True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['level_0'] not found in axis"

# %%
ProductWeight.drop(columns = ['match'], inplace= True)

# %%
merge['weight'] = ProductWeight

# %%
merge

# %%
ProductWeight

# %%
merge

# %%
merge.drop(columns='level_0', inplace= True)

# %%
merge.drop(columns= 'index', inplace= True)

# %%
merge

# %%
Question1 = merge.groupby('LIFESTAGE')['TOT_SALES'].sum().reset_index()

# %% [markdown]
# Who spends the most on chips (total sales), describing customers by lifestage and
# how premium their general purchasing behaviour is

# %%
Question1.sort_values(by = ['TOT_SALES'], ascending=False)

# %%
merge.groupby('PREMIUM_CUSTOMER')[['TOT_SALES', 'PROD_QTY']].sum().sort_values(by = ['TOT_SALES'], \
                                                                               ascending= False)

# %% [markdown]
# How many customers are in each segment

# %%
Q2 = merge.groupby('PREMIUM_CUSTOMER')[['TOT_SALES']].count().sort_values(by = ['TOT_SALES'], ascending= False)\
.rename(columns={'TOT_SALES': 'Number_of_customer'})
Q2

# %% [markdown]
# How many chips are bought per customer by segment

# %%
merge.groupby('LYLTY_CARD_NBR').count().groupby('PREMIUM_CUSTOMER').count()

# %%
merge.groupby('PREMIUM_CUSTOMER').count()
# Out:
#                    index  LYLTY_CARD_NBR  LIFESTAGE    DATE  STORE_NBR  \
# PREMIUM_CUSTOMER
# Budget             92943           92943      92943   92943      92943
# Mainstream        101770          101770     101770  101770     101770
# Premium            69545           69545      69545   69545      69545
#
#                   TXN_ID  PROD_NBR  PROD_NAME  PROD_QTY  TOT_SALES  weight
# PREMIUM_CUSTOMER
# Budget             92943     92943      92943     92943      92943   92943
# Mainstream        101770    101770     101770    101770     101770  101770
# Premium            69545     69545      69545     69545      69545   69545

# %%
merge[merge['PREMIUM_CUSTOMER'] == 'Budget'].groupby('LYLTY_CARD_NBR')['PROD_QTY'].count().sort_values()
# Out:
# LYLTY_CARD_NBR
# 192473     1
# 49338      1
# 192199     1
# 192234     1
# 192274     1
#           ..
# 23192     16
# 104117    16
# 179228    16
# 105026    16
# 230078    17
# Name: PROD_QTY, Length: 24450, dtype: int64

# %% [markdown]
# What's the average chip price by customer segment

# %%
# ?plt.plot

# %%
potato.groupby('PROD_NAME').count()
# Out:
#                                         DATE  STORE_NBR  LYLTY_CARD_NBR  \
# PROD_NAME
# Burger Rings 220g                       1564       1564            1564
# CCs Nacho Cheese    175g                1498       1498            1498
# CCs Original 175g                       1514       1514            1514
# CCs Tasty Cheese    175g                1539       1539            1539
# Cheetos Chs & Bacon Balls 190g          1479       1479            1479
# ...                                      ...        ...             ...
# WW Sour Cream &OnionStacked Chips 160g  1483       1483            1483
# WW Supreme Cheese   Corn Chips 200g     1509       1509            1509
# Woolworths Cheese   Rings 190g          1516       1516            1516
# Woolworths Medium   Salsa 300g          1430       1430            1430
# Woolworths Mild     Salsa 300g          1491       1491            1491
#
#                                         TXN_ID  PROD_NBR  PROD_QTY  TOT_SALES
# PROD_NAME
# Burger Rings 220g                         1564      1564      1564       1564
# CCs Nacho Cheese    175g                  1498      1498      1498       1498
# CCs Original 175g                         1514      1514      1514       1514
# CCs Tasty Cheese    175g                  1539      1539      1539       1539
# Cheetos Chs & Bacon Balls 190g            1479      1479      1479       1479
# ...                                        ...       ...       ...        ...
# WW Sour Cream &OnionStacked Chips 160g    1483      1483      1483       1483
# WW Supreme Cheese   Corn Chips 200g       1509      1509      1509       1509
# Woolworths Cheese   Rings 190g            1516      1516      1516       1516
# Woolworths Medium   Salsa 300g            1430      1430      1430       1430
# Woolworths Mild     Salsa 300g            1491      1491      1491       1491
#
# [114 rows x 7 columns]

# %%
#b.plot(kind = 'line', x= 'DATE')
b.loc[len(b)]=[2018-12-25,0]
b.plot(kind = 'line', x= 'DATE')
b
# Out:
#                     DATE  PROD_QTY
# 0    2018-07-01 00:00:00       724
# 1    2018-07-02 00:00:00       711
# 2    2018-07-03 00:00:00       722
# 3    2018-07-04 00:00:00       714
# 4    2018-07-05 00:00:00       712
# ..                   ...       ...
# 366                 1981         0
# 367                 1981         0
# 368                 1981         0
# 369                 1981         0
# 370                 1981         0
#
# [371 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 0, 10])

plt.plot(xpoints, ypoints)
plt.show()
